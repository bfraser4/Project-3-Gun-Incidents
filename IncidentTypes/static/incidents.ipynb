# %%
import pandas as pd 

police = pd.read_csv('incident_types.csv')
police

police_df = pd.DataFrame(police)
by_year = police.loc[police['Injury Intent'] == 'Firearm Homicide']
intent = by_year.sort_values(by=['Total Deaths (#)'], ascending=False)
intent.head(25)

# by_year.to_csv('us_suicides.csv')
# Out:
#               State  First Year   Last Year     Injury Intent  \
# 265   United States        2016        2020  Firearm Homicide
# 28       California        2016        2020  Firearm Homicide
# 258           Texas        2016        2020  Firearm Homicide
# 54          Florida        2016        2020  Firearm Homicide
# 82         Illinois        2016        2020  Firearm Homicide
# 64          Georgia        2016        2020  Firearm Homicide
# 213            Ohio        2016        2020  Firearm Homicide
# 231    Pennsylvania        2016        2020  Firearm Homicide
# 200  North Carolina        2016        2020  Firearm Homicide
# 112       Louisiana        2016        2020  Firearm Homicide
# 152        Missouri        2016        2020  Firearm Homicide
# 253       Tennessee        2016        2020  Firearm Homicide
# 132        Michigan        2016        2020  Firearm Homicide
# 2           Alabama        2016        2020  Firearm Homicide
# ...
