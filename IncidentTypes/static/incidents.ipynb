# %%
import pandas as pd 

police = pd.read_csv('incident_types.csv')
police

police_df = pd.DataFrame(police)
by_year = police.sort_values(by=['Total Deaths (#)', 'Injury Intent'], ascending=False)
by_year.head(10)

# by_year.to_csv('us_suicides.csv')
# Out:
#              State  First Year   Last Year       Injury Intent  \
# 264  United States        2016        2020  All Firearm Deaths
# 268  United States        2016        2020     Firearm Suicide
# 265  United States        2016        2020    Firearm Homicide
# 259          Texas        2016        2020  All Firearm Deaths
# 24      California        2016        2020  All Firearm Deaths
# 56         Florida        2016        2020  All Firearm Deaths
# 262          Texas        2016        2020     Firearm Suicide
# 57         Florida        2016        2020     Firearm Suicide
# 60         Georgia        2016        2020  All Firearm Deaths
# 232   Pennsylvania        2016        2020  All Firearm Deaths
#
#      Total Deaths (#)  Avg. Yearly Deaths (#)    Population  \
# 264          203100.0                 40620.0  1.633738e+09
# 268          119457.0                 23891.0  1.633738e+09
# 265           76713.0                 15343.0  1.633738e+09
# ...
