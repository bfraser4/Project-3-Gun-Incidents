# %%
import pandas as pd

data_xls = pd.read_excel('Demographics.xlsx', 'Demographics', dtype=str, index_col=None)
data_xls.to_csv('demographics.csv', encoding='utf-8', index=False)

# %%
#read CSV
demographics = pd.read_csv('Demographics.csv')

demographics.head(10)
# Out:
#      State  First Year  Last Year       Injury Intent       Race / Ethnicity  \
# 0  Alabama        2016       2020  All Firearm Deaths  All Races/Ethnicities
# 1  Alabama        2016       2020  All Firearm Deaths  All Races/Ethnicities
# 2  Alabama        2016       2020  All Firearm Deaths  All Races/Ethnicities
# 3  Alabama        2016       2020  All Firearm Deaths     non-Hispanic Black
# 4  Alabama        2016       2020  All Firearm Deaths     non-Hispanic Black
# 5  Alabama        2016       2020  All Firearm Deaths     non-Hispanic Black
# 6  Alabama        2016       2020  All Firearm Deaths     non-Hispanic white
# 7  Alabama        2016       2020  All Firearm Deaths     non-Hispanic white
# 8  Alabama        2016       2020  All Firearm Deaths     non-Hispanic white
# 9  Alabama        2016       2020  All Firearm Deaths                 Latinx
#
#         Gender  Total Deaths (#)  Population  Age-adjusted Rate (per 100,000)
# 0  All Genders            5451.0  24450635.0                        22.401011
# 1         Male            4550.0  11826020.0                        38.738411
# 2       Female             901.0  12624615.0                         7.239940
# 3  All Genders            2131.0   6608065.0                        32.012270
# 4         Male            1899.0   3073003.0                        61.060640
# 5       Female             232.0   3535062.0                         6.532940
# 6  All Genders            3200.0  16216113.0                        18.741010
# 7         Male            2553.0   7922501.0                        30.553120
# 8       Female             647.0   8293612.0                         7.783910
# 9  All Genders              84.0   1081919.0                         8.370970
