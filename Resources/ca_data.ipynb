# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('CA_only.csv')
df
# Out:
#                                incident_characteristics  incident_id  \
# 0     Shot - Wounded/Injured||Shot - Dead (murder, a...       460726
# 1     Shot - Wounded/Injured||Shot - Dead (murder, a...       479580
# 2     Shot - Wounded/Injured||Shot - Dead (murder, a...       480311
# 3     Shot - Wounded/Injured||Shot - Dead (murder, a...       480358
# 4     Shot - Wounded/Injured||Shot - Dead (murder, a...       481213
# ...                                                 ...          ...
# 4949          Shot - Dead (murder, accidental, suicide)      1082094
# 4950          Shot - Dead (murder, accidental, suicide)      1082096
# 4951          Shot - Dead (murder, accidental, suicide)      1082266
# 4952          Shot - Dead (murder, accidental, suicide)      1082392
# 4953          Shot - Dead (murder, accidental, suicide)      1082091
#
#             date       state   city_or_county                        address  \
# ...
